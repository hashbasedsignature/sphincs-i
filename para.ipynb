# %%
#tsec,osec,hashbytes = 127,128,16
#tsec,osec,hashbytes = 192,192,24
#tsec,osec,
#hashbytes = 32

maxsigs=2**64
F = RealField(256+100)


def pow(p,e):
    return F(p)**e
def qhitprob(qs,r):
    p = F(1/leaves)
    return binomial(qs,r)*(pow(p,r))*(pow(1-p,qs-r))

def run(l,w):
    s=l*(w-1)//2
    dp=[]
    for i in range(0,l+1):
        dp.append([])
        for j in range(0,s+1):
            dp[i].append(0)

    dp[0][0]=1
    for i in range(1,l+1):
        for j in range(0,s+1):
            for k in range(0,w):
                if k>j:
                    continue
                dp[i][j]+=dp[i-1][j-k] 
    return dp[l][s]

lenmap={}

for osec in [128,192,256]:
    lenmap[osec]={}
    for w in range(8,50):
        lenmap[osec][w]=99999 
        for i in range(25,100): 
            if F(log(F(run(i,w)))/log2)>osec:
                lenmap[osec][w]=i 
                print(osec,w,i,w*i/2.0)
                break
print('preprocess end')
# Out:
# 128 8 45 180.000000000000
# 128 9 43 193.500000000000
# 128 10 41 205.000000000000
# 128 11 39 214.500000000000
# 128 12 38 228.000000000000
# 128 13 37 240.500000000000
# 128 14 36 252.000000000000
# 128 15 35 262.500000000000
# 128 16 34 272.000000000000
# 128 17 33 280.500000000000
# 128 18 33 297.000000000000
# 128 19 32 304.000000000000
# 128 20 32 320.000000000000
# 128 21 31 325.500000000000
# 128 22 31 341.000000000000
# 128 23 30 345.000000000000
# 128 24 30 360.000000000000
# 128 25 29 362.500000000000
# 128 26 29 377.000000000000
# 128 27 29 391.500000000000
# 128 28 29 406.000000000000
# 128 29 28 406.000000000000
# 128 30 28 420.000000000000
# 128 31 28 434.000000000000
# 128 32 27 432.000000000000
# 128 33 27 445.500000000000
# 128 34 27 459.000000000000
# 128 35 27 472.500000000000
# 128 36 27 486.000000000000
# 128 37 26 481.000000000000
# 128 38 26 494.000000000000
# 128 39 26 507.000000000000
# 128 40 26 520.000000000000
# 128 41 26 533.000000000000
# 128 42 26 546.000000000000
# 128 43 25 537.500000000000
# 128 44 25 550.000000000000
# 128 45 25 562.500000000000
# 128 46 25 575.000000000000
# 128 47 25 587.500000000000
# 128 48 25 600.000000000000
# 128 49 25 612.500000000000
# 192 8 66 264.000000000000
# 192 9 63 283.500000000000
# 192 10 60 300.000000000000
# 192 11 58 319.000000000000
# 192 12 56 336.000000000000
# 192 13 54 351.000000000000
# 192 14 53 371.000000000000
# 192 15 51 382.500000000000
# 192 16 50 400.000000000000
# 192 17 49 416.500000000000
# 192 18 48 432.000000000000
# 192 19 47 446.500000000000
# 192 20 46 460.000000000000
# 192 21 46 483.000000000000
# 192 22 45 495.000000000000
# 192 23 44 506.000000000000
# 192 24 44 528.000000000000
# 192 25 43 537.500000000000
# 192 26 43 559.000000000000
# 192 27 42 567.000000000000
# 192 28 42 588.000000000000
# 192 29 41 594.500000000000
# 192 30 41 615.000000000000
# 192 31 41 635.500000000000
# 192 32 40 640.000000000000
# 192 33 40 660.000000000000
# 192 34 40 680.000000000000
# 192 35 39 682.500000000000
# 192 36 39 702.000000000000
# 192 37 39 721.500000000000
# 192 38 38 722.000000000000
# 192 39 38 741.000000000000
# 192 40 38 760.000000000000
# 192 41 38 779.000000000000
# 192 42 38 798.000000000000
# 192 43 37 795.500000000000
# 192 44 37 814.000000000000
# 192 45 37 832.500000000000
# 192 46 37 851.000000000000
# 192 47 36 846.000000000000
# 192 48 36 864.000000000000
# 192 49 36 882.000000000000
# 256 8 88 352.000000000000
# 256 9 83 373.500000000000
# 256 10 79 395.000000000000
# 256 11 76 418.000000000000
# 256 12 74 444.000000000000
# 256 13 71 461.500000000000
# 256 14 69 483.000000000000
# 256 15 68 510.000000000000
# 256 16 66 528.000000000000
# 256 17 65 552.500000000000
# 256 18 63 567.000000000000
# 256 19 62 589.000000000000
# 256 20 61 610.000000000000
# 256 21 60 630.000000000000
# 256 22 59 649.000000000000
# 256 23 59 678.500000000000
# 256 24 58 696.000000000000
# 256 25 57 712.500000000000
# 256 26 56 728.000000000000
# 256 27 56 756.000000000000
# 256 28 55 770.000000000000
# 256 29 55 797.500000000000
# 256 30 54 810.000000000000
# 256 31 54 837.000000000000
# 256 32 53 848.000000000000
# 256 33 53 874.500000000000
# 256 34 52 884.000000000000
# 256 35 52 910.000000000000
# 256 36 51 918.000000000000
# 256 37 51 943.500000000000
# 256 38 51 969.000000000000
# 256 39 50 975.000000000000
# 256 40 50 1000.00000000000
# 256 41 50 1025.00000000000
# 256 42 49 1029.00000000000
# 256 43 49 1053.50000000000
# 256 44 49 1078.00000000000
# 256 45 49 1102.50000000000
# 256 46 48 1104.00000000000
# 256 47 48 1128.00000000000
# 256 48 48 1152.00000000000
# 256 49 48 1176.00000000000
# preprocess end

# %%
max_size=49856
max_hashcalls=327696

def size(sec,h,d,b,k,w1,hashbytes):
    l=lenmap[sec][w1]
    return ((b+1)*k+h+l*d+1)*hashbytes


def split(h,d):
    ans=[0 for i in range(d)]
    for i in range(h):
        ans[i%d]+=1
    return ans

def speed(sec,h,d,b,k,w1):
    l=lenmap[sec][w1]
    ans=k*(2**b)*(2)
    ans+=d*(2**(h/d)*(l*w1+1))
    return ans


def sec(h,d,b,k,w1):
    s=F(0)
    for r in range(100): # in fact, qhitprob(maxsigs,r)<2^{-256}*2^{-64} when r>100. Thus we can omit all r>100
        p=F(1-(1-1/F(2**b))^r)**k
        s+=qhitprob(maxsigs,r)*p
    return -F(log(F(s))/log2)

def factor(h):
    ans=[]
    for d in range(6,h):
        if h%d==0:
            ans.append(d)
    return ans


paras={}
paras[128]={}
paras[192]={}
paras[256]={}

paras[128]['small']=(63,7,12,14,16)
paras[128]['fast']=(66,22,6,33,16)

paras[192]['small']=(63,7,14,17,16)
paras[192]['fast']=(66,22,8,33,16)

paras[256]['small']=(64,8,14,22,16)
paras[256]['fast']=(68,17,9,35,16)


for osec in [128,192,256]:
    for ty in ['small','fast']:
        h,d,b,k,w1=paras[osec][ty]
        max_size=size(osec,h,d,b,k,w1,osec//8)
        max_hashcalls=speed(osec,h,d,b,k,w1)
        print(osec,ty,max_size,max_hashcalls)
        best_szsp=(max_size,max_hashcalls)
        best_spsz=(max_hashcalls,max_size)
        para_szsp=(h,d,b,k,w1)
        para_spsz=(h,d,b,k,w1)
        for h in [63,64,65,66,68]:
            leaves=2**h
            for b in range(3,15):
                for k in range(6,40):
                    if sec(h,0,b,k,0)>=osec-1:
                        for d in factor(h):
                            for w1 in range(8,50): 
                                sz=size(osec,h,d,b,k,w1,osec//8)
                                sp=speed(osec,h,d,b,k,w1)
                                if sec(h,d,b,k,w1)>=osec-1 and sz<=max_size and sp<max_hashcalls:
                                    if (sz,sp)<best_szsp:
                                        best_szsp=(sz,sp)
                                        para_szsp=(h,d,b,k,w1,lenmap[osec][w1])
                                    if (sp,sz)<best_spsz:
                                        best_spsz=(sp,sz)
                                        para_spsz=(h,d,b,k,w1,lenmap[osec][w1])
                            break
            print(h)
        print(para_szsp,best_szsp)
        print(para_spsz,best_spsz)
# Out:
# 128 small 7744 2067968
# 63
# 64
# 65
# 66
# 68
# (64, 8, 13, 12, 32, 27) (7184, 1968128)
# (64, 8, 12, 13, 21, 31) (1441792, 7712)
# 128 fast 16736 100144
# 63
# 64
# 65
# 66
# 68
# (66, 22, 6, 33, 16) (16736, 100144)
# (66, 22, 6, 33, 16) (100144, 16736)
# 192 small 16056 3427840
# 63
# 64
# 65
# 66
# 68
# (64, 8, 13, 18, 38, 38) (14904, 3254272)
# (64, 8, 12, 20, 25, 43) (2367488, 16056)
# 192 fast 35136 157872
# 63
# 64
# 65
# 66
# 68
# (66, 22, 8, 33, 16) (35136, 157872)
# (66, 22, 8, 33, 16) (157872, 35136)
# 256 small 29536 2885632
# 63
# 64
# 65
# 66
# 68
# (64, 8, 12, 27, 22, 59) (28416, 2881536)
# (64, 8, 12, 27, 18, 63) (2545664, 29440)
# 256 fast 49312 323344
# 63
# 64
# 65
# 66
# 68
# (68, 17, 9, 35, 16) (49312, 323344)
# (68, 17, 9, 35, 16) (323344, 49312)
